# %%
import pandas as pd

# %%
df = pd.read_csv('test_data.csv', index_col=[0])

# %%
df.reset_index(inplace=True, drop='True')

# %%
df.groupby('Author').agg({'Text':'count'})
# Out:
#                                 Text
# Author
# Агния Барто                      196
# Александр Блок                  1259
# Александр Пушкин                 859
# Алексей Константинович Толстой   258
# Алексей Плещеев                  199
# Андрей Белый                     391
# Андрей Вознесенский              203
# Андрей Дементьев                 452
# Анна Ахматова                    892
# Арсений Тарковский               127
# Афанасий Фет                     886
# Белла Ахмадулина                 296
# Борис Пастернак                  305
# Борис Рыжий                      113
# Булат Окуджава                   279
# Валерий Брюсов                  1572
# Василий Жуковский                232
# Велимир Хлебников                112
# Вероника Тушнова                 167
# Владимир Высоцкий                720
# Владимир Маяковский             1295
# Гавриил Державин                 246
# Даниил Хармс                     116
# Дмитрий Мережковский             323
# ...

# %%
df
# Out:
#                                                     Text       Author
# 0      Весна, весна на улице,\r\nВесенние деньки!\r\n...  Агния Барто
# 1      Мы не заметили жука\r\nИ рамы зимние закрыли,\...  Агния Барто
# 2      Написано вместе с Павлом Барто — Ах ты, девочк...  Агния Барто
# 3      Шла вчера я за водою,\r\nА у нас ведро худое.\...  Агния Барто
# 4      Кто, кто\r\nВ этой комнате живёт?\r\nКто, кто\...  Агния Барто
# ...                                                  ...          ...
# 24292  Этот пруд за оградой,\r\nДеревья ничьи\r\nБыли...   Юнна Мориц
# 24293  Это яблони так благовонны,\r\nЭто яблоки в лис...   Юнна Мориц
# 24294  У нас такая синева\r\nВ окне — от близости рек...   Юнна Мориц
# 24295  Изменился климат, вымерли подчистую\r\nмамонты...   Юнна Мориц
# 24296                                                NaN   Юнна Мориц
#
# [24297 rows x 2 columns]
